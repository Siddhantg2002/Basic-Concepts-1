# %%
#IMPORTING DATA
import pandas as pd
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
music
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
#SEPERATING INPUT
import pandas as pd
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
x=music.drop(columns=['genre'])
x
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
#SEPERATING OUTPUT
import pandas as pd
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
x=music.drop(columns=['genre'])
y=music['genre']
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
#MODEL SELECTION AND PREDICTION
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings("ignore")
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
x=music.drop(columns=['genre'])
y=music['genre']
model=DecisionTreeClassifier()
#Passing the entire data as training set
#The fit() method takes the training data as arguments
model.fit(x,y)
predictions=model.predict([ [21,1],[32,0] ])
predictions
# Out:
# array(['HipHop', 'Classical'], dtype=object)

# %%
#CALCULATING ACCURACY OF THE MODEL
#(SPLITTING THE DATASET INTO TRAINING(70-80%) AND TESTING(30-20%))
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
x=music.drop(columns=['genre'])
y=music['genre']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8)
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
predictions=model.predict(x_test)
score=accuracy_score(y_test, predictions)
score
# Out:
# 0.75

# %%
#LOADING MODEL/PERSISITING MODEL
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from joblib import memory
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
x=music.drop(columns=['genre'])
y=music['genre']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8)
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
joblib.dump(model,'Music.joblib')
# predictions=model.predict(x_test)
# score=accuracy_score(y_test, predictions)
# score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j1/f0b1pqkx69b2hbxh5p5h72940000gn/T/ipykernel_36429/3138503529.py in <module>
#      13 model=DecisionTreeClassifier()
#      14 model.fit(x_train,y_train)
# ---> 15 joblib.dump(model,'Music.joblib')
#      16 # predictions=model.predict(x_test)
#      17 # score=accuracy_score(y_test, predictions)
#
# NameError: name 'joblib' is not defined

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import warnings
warnings.filterwarnings("ignore")
music=pd.read_csv("/Users/siddhant/Desktop/SID/CODES/PYTHON/Machine Learning/Decision trees/music.csv")
x=music.drop(columns=['genre'])
y=music['genre']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8)
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
tree.export_graphviz(model,out_file='music-recommender.dot',feature_names=['age','gender'],class_names=sorted(y.unique()),label='all',rounded=True,filled=True)
